# %%
import pandas as pd 
from sklearn.model_selection import train_test_split

# %%
path = "../data/raw/ejalisco2016.csv"
df = pd.read_csv(path, encoding= "ISO-8859-1")

# %%
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)

# %%
train_data.head(5)
# Out:
#      CLAVE DE INMUEBLE TECNOLOGIA INSTALADA ANCHO DE BANDA CONTRATADO 2014  \
# 4483          1405322E          INALAMBRICA                           2 MB
# 2333          1405225E                 iMAX                           2 MB
# 799           1408861J                 iMAX                           2 MB
# 354           1405004F                 iMAX                           2 MB
# 1801          1401476H                 iMAX                           2 MB
#
#      INSTITUCION        NOMBRE DEL CENTRO TURNO/HORARIO       NIVEL  REGION  \
# 4483         SEJ             PEDRO MORENO      MATUTINO  SECUNDARIA     SUR
# 2333         SEJ         VICENTE GUERRERO    VESPERTINO    PRIMARIA     SUR
# 799          SEJ           RAMON G BONFIL      MATUTINO    PRIMARIA  CENTRO
# 354          SEJ             USAER TUXPAN      MATUTINO    ESPECIAL     SUR
# 1801         SEJ  JOSE MA MORELOS Y PAVON    VESPERTINO    PRIMARIA   NORTE
#
#                    MUNICIPIO    LOCALIDAD  \
# 4483             SAN GABRIEL       APANGO
# 2333  TEOCUITATLAN DE CORONA   AGUA HONDA
# 799              GUADALAJARA  GUADALAJARA
# 354                   TUXPAN       TUXPAN
# 1801                HUEJUCAR    LAS CA_AS
#
#                                               DOMICILIO CODIGO POSTAL  \
# 4483                                  PORFIRIO DIAZ S/N         49710
# 2333                                           CONOCIDO         49250
# 799   VASCO UÑEZ DE BALBOA 2699 ENTRE FRANCISCO VAZQ...         44930
# 354                                AVENIDA TIZATIRLA 37         49800
# 1801                                         MORELOS 23         46260
#
#           LONGITUD     LATITUD       ESTATUS
# 4483  -103.7115472  19.7825444    SUSPENDIDO
# 2333  -103.3862611  20.1350306  SIN SERVICIO
# 799       -103.374       20.74        ACTIVO
# 354   -103.3759833     19.5545        ACTIVO
# 1801  -103.3429333  22.3079917  SIN SERVICIO

# %%
test_data.head(5)
# Out:
#      CLAVE DE INMUEBLE TECNOLOGIA INSTALADA ANCHO DE BANDA CONTRATADO 2014  \
# 1575     GOB_AHUALULCO                 iMAX                           2 MB
# 6444           SSJ_400                 ADSL                           2 MB
# 4622          1404880H                 ADSL                          10 MB
# 2107          1404259J                 iMAX                           2 MB
# 1360          1410827C                 iMAX                           2 MB
#
#      INSTITUCION      NOMBRE DEL CENTRO TURNO/HORARIO     NIVEL   REGION  \
# 1575         GOB  PRESIDENCIA MUNICIPAL           NaN       NaN   VALLES
# 6444         SSJ   TEPEHUAJE DE MORELOS           N/D       N/D   VALLES
# 4622         SEJ       FRAY JUAN LARIOS      MATUTINO  PRIMARIA      SUR
# 2107         SEJ           NIÑOS HEROES      MATUTINO  PRIMARIA  CIENEGA
# 1360         SEJ         RAFAEL JIMENEZ      MATUTINO  PRIMARIA   CENTRO
#
#                  MUNICIPIO                LOCALIDAD  \
# 1575  AHUALULCO DE MERCADO                      NaN
# 6444    SAN MARTIN HIDALGO  EL TEPEHUAJE DE MORELOS
# 4622                SAYULA                   SAYULA
# 2107              TOTOTLAN  SAN AGUSTIN (CAPULINES)
# 1360                TONALA                   TONALA
#
#                                    DOMICILIO CODIGO POSTAL        LONGITUD  \
# 1575                      GONZALEZ MADRID 11           NaN  103¡58'36.13"
# 6444                              OBREGON 70         46785    -103.9122222
# 4622                              GALEANA 20         49300    -103.6014917
# 2107  MIGUEL HIDALGO SN SAN AGUSTIN TOTOTLAN         47730    -102.7171111
# 1360                   HIDALGO  2 SAN GASPAR         45400    -103.2522222
#
#           LATITUD       ESTATUS
# 1575  20¡42'4.15         ACTIVO
# 6444   20.4336111    SUSPENDIDO
# 4622   19.8904611    SUSPENDIDO
# 2107   20.6341944  SIN SERVICIO
# 1360   20.6811111        ACTIVO

# %%
test_data.to_csv(path_or_buf="../data/raw/test.csv", index = False)
train_data.to_csv(path_or_buf="../data/raw/train.csv", index = False)
